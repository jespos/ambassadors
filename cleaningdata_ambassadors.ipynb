# %% [markdown]
# # A Visual Representation of COS Ambassador Data
# ----
# ### Center for Open Science Ambassadors are a global network of over 200 advocates increasing conversations around open science and promoting open science initiatives.

# %% [markdown]
# ### **Getting Started**
#
# On Mac OS, I created a virtual environment called **mapping** using Conda.
#
# * conda create -n **mapping**
#
# * source activate **mapping**
#
# -----
# #### **Programs to Install and Run (you may require more)**
#
#
# * Matplotlib
#
# * Pandas
#
# * Numpy
#
# * Basemap
#
# * Geopy
#
# * Folium

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json

# %%
df = pd.read_csv('ambassadors_list.csv')

df.head()

# %%
df.tail()
# Out:
#     First Name   Last Name                      Email           City  \
# 222    Mathew   Vis-Dunbar  mathew.vis-dunbar@ubc.ca         Kelowna
# 223       Jan         Röer       jan.roeer@uni-wh.de          Witten
# 224    Etienne      Roesch   e.b.roesch@reading.ac.uk            NaN
# 225      Stacy  Winchester   winches2@mailbox.sc.edu        Columbia
# 226      Jamie      Bedics   jbedics@callutheran.edu   Thousand Oaks
#
#                 State  Country         Region  \
# 222  British Columbia   Canada  North America
# 223               NaN  Germany         Europe
# 224           Reading  England         Europe
# 225    South Carolina      USA  North America
# 226        California      USA  North America
#
#                              Institution/Organization  \
# 222  University of British Columbia - Okanagan Campus
# 223                        Witten/Herdecke University
# 224                             University of Reading
# 225                      University of South Carolina
# 226                           Cal Lutheran University
#
#                       Domain Mailing Address Prereg Challenge  \
# 222                Libraries             NaN              NaN
# 223  Experimental Psychology             NaN              NaN
# 224        Cognitive Science             NaN              NaN
# 225                Libraries             NaN              NaN
# 226                Libraries             NaN              NaN
#
#     ambassador training date
# 222                 04/04/18
# 223                 04/20/18
# 224                 04/25/18
# 225                 07/17/18
# 226                 07/18/18

# %% [markdown]
# After examining my data, I want to drop columns that I know won't be useful for my analyses.
# I don't need information like name, email, mailing address. I use the Pandas .drop() function.
# I create a variable, drop_columns, and set it equal to the column names I want to remove.
# Inside the .drop() function. Passing the variable to the columns parameter is more intuitive and inplace means that the changes will be made directly into our object.

# %%
drop_columns = ['First Name', 'Last Name', 'Email', 'Mailing Address', 'Prereg Challenge']

df.drop(columns=drop_columns, inplace=True)

df.head()
# Out:
#         City       State      Country         Region  \
# 0       Bonn         NaN      Germany         Europe
# 1  Eindhoven         NaN  Netherlands         Europe
# 2   Grenoble         NaN       France         Europe
# 3  Riverside  California          USA  North America
# 4     Tacoma  Washington          USA  North America
#
#                Institution/Organization      Domain ambassador training date
# 0                  MPI Collective Goods  Psychology                   2/3/15
# 1                             Eindhoven  Psychology                   2/3/15
# 2             Université Grenoble Alpes  Psychology                   2/3/15
# 3  University of California - Riverside  Psychology                   2/3/15
# 4                      Pacific Lutheran  Psychology                   2/3/15

# %% [markdown]
# I want to rename some columns. Institution/Organization to Organization and ambassador training date to 'Training Date'

# %%
df.rename(columns={'Institution/Organization': 'Organization', 'ambassador training date': 'Training Date'}, inplace=True)
df.head()
# Out:
#         City       State      Country         Region  \
# 0       Bonn         NaN      Germany         Europe
# 1  Eindhoven         NaN  Netherlands         Europe
# 2   Grenoble         NaN       France         Europe
# 3  Riverside  California          USA  North America
# 4     Tacoma  Washington          USA  North America
#
#                            Organization      Domain Training Date
# 0                  MPI Collective Goods  Psychology        2/3/15
# 1                             Eindhoven  Psychology        2/3/15
# 2             Université Grenoble Alpes  Psychology        2/3/15
# 3  University of California - Riverside  Psychology        2/3/15
# 4                      Pacific Lutheran  Psychology        2/3/15

# %% [markdown]
# I want to look at some information including how each value in our table is classified (i.e. object type, float type). To do so, I can use the .info() function to gather some information on our table. .dtypes will also give us this information, but only on what our object types are.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 7 columns):
# City             217 non-null object
# State            139 non-null object
# Country          226 non-null object
# Region           225 non-null object
# Organization     225 non-null object
# Domain           150 non-null object
# Training Date    214 non-null object
# dtypes: object(7)
# memory usage: 12.5+ KB

# %%
df.dtypes
# Out:
# City             object
# State            object
# Country          object
# Region           object
# Organization     object
# Domain           object
# Training Date    object
# dtype: object

# %% [markdown]
# We notice that most of this makes sense except our training data column - which is labeled as an 'object.' For analyses I want to do, it would be better if these values were of the datetime type.

# %%
df['Training Date'] #showing this column
# Out:
# 0        2/3/15
# 1        2/3/15
# 2        2/3/15
# 3        2/3/15
# 4        2/3/15
# 5        2/3/15
# 6        2/3/15
# 7      02/24/15
# 8       4/30/15
# 9       4/30/15
# 10      4/30/15
# 11      4/30/15
# 12      4/30/15
# 13      4/30/15
# 14      4/30/15
# 15      4/30/15
# 16      4/30/15
# 17      4/30/15
# 18      4/30/15
# 19      4/30/15
# 20       9/9/15
# 21       9/9/15
# 22      9/21/15
# 23      9/21/15
# 24      9/21/15
# 25      9/21/15
# 26      9/21/15
# 27      9/21/15
# 28     10/21/15
# 29       1/6/16
#          ...
# 197    11/08/17
# 198    11/21/17
# 199    11/27/17
# 200    11/27/17
# 201    11/28/17
# 202     12/7/17
# 203    01/03/18
# 204    01/05/18
# 205    01/12/18
# 206    01/19/18
# 207    01/23/18
# 208         NaN
# 209    02/05/18
# 210    02/07/18
# 211    02/13/18
# 212    02/15/18
# 213    02/20/18
# 214    02/27/18
# 215       03/08
# 216    03/08/18
# 217     3/15/18
# 218    03/19/18
# 219    03/27/18
# 220         NaN
# 221    04/04/18
# 222    04/04/18
# 223    04/20/18
# 224    04/25/18
# 225    07/17/18
# 226    07/18/18
# Name: Training Date, Length: 227, dtype: object

# %% [markdown]
# To change these values in the Training Date column to the 'datetime' type, Pandas has a convenient function to do so. In this case, I am using pd.to_datetime() and passing in my column.

# %%
df['Training Date'] = pd.to_datetime(df['Training Date'], errors='coerce')

# %%
df.dtypes
# Out:
# City                     object
# State                    object
# Country                  object
# Region                   object
# Organization             object
# Domain                   object
# Training Date    datetime64[ns]
# dtype: object

# %%
df.head()
# Out:
#         City       State      Country         Region  \
# 0       Bonn         NaN      Germany         Europe
# 1  Eindhoven         NaN  Netherlands         Europe
# 2   Grenoble         NaN       France         Europe
# 3  Riverside  California          USA  North America
# 4     Tacoma  Washington          USA  North America
#
#                            Organization      Domain Training Date
# 0                  MPI Collective Goods  Psychology    2015-02-03
# 1                             Eindhoven  Psychology    2015-02-03
# 2             Université Grenoble Alpes  Psychology    2015-02-03
# 3  University of California - Riverside  Psychology    2015-02-03
# 4                      Pacific Lutheran  Psychology    2015-02-03

# %% [markdown]
# Particularly in the State column, I would like to clean up NaN to be blank. International Ambassadors typically only have a City and Country listed, so removing NaN will make the sheet look cleaner. I made the decision to remove the NaN from all the columns except the Training Date.

# %%
fill_values = {'City': '', 'State': '', 'Country': '', 'Region': '', 'Organization': '', 'Domain': ''}

df.fillna(fill_values, inplace=True)

df.head()
# Out:
#         City       State      Country         Region  \
# 0       Bonn                  Germany         Europe
# 1  Eindhoven              Netherlands         Europe
# 2   Grenoble                   France         Europe
# 3  Riverside  California          USA  North America
# 4     Tacoma  Washington          USA  North America
#
#                            Organization      Domain Training Date
# 0                  MPI Collective Goods  Psychology    2015-02-03
# 1                             Eindhoven  Psychology    2015-02-03
# 2             Université Grenoble Alpes  Psychology    2015-02-03
# 3  University of California - Riverside  Psychology    2015-02-03
# 4                      Pacific Lutheran  Psychology    2015-02-03

# %% [markdown]
# Our Domain column looks neat and pretty when viewing the first 5 values. But, the data are actually a mess. Let's take a look. Particularly, I want to take a look at how many of the same values occur, so I am going to run the .value_counts() function on values in our Domain column.

# %%
df['Domain'].value_counts()
# Out:
#                                                                                                             77
# Psychology                                                                                                  21
# Libraries                                                                                                   18
# Psych                                                                                                       13
# Ecology                                                                                                      4
# Libraries - OSF Institutions                                                                                 3
# PHD student - Psychology                                                                                     2
# Libraries                                                                                                    2
# Cognitive Science                                                                                            2
# Data Services Librarian                                                                                      2
# Cognitive Psych and Cognitive Neuroscience                                                                   2
# Brain Stimulation & Cognitive Neuroscience Lab Manager                                                       2
# Research Data Librarian                                                                                      2
# Clinical Psychology                                                                                          2
# Econ                                                                                                         2
# ECE                                                                                                          1
# Personality Psychology                                                                                       1
# PhD - second year                                                                                            1
# Open Science Enthusiast                                                                                      1
# Completed her PhD in Implicit Theory of mind. Started a post-doc                                             1
# Digital Initiatives and Information Technology Librarian                                                     1
# ecology                                                                                                      1
# Communications                                                                                               1
# Data Management Consultant                                                                                   1
# Nutrition - NutriXiv                                                                                         1
# QA/QC Officer; PhD from Cornell                                                                              1
# Business Management                                                                                          1
# psych/stats                                                                                                  1
# Medical (MD student, cancer research)                                                                        1
# Social & Evolutionary Psychology                                                                             1
#                                                                                                             ..
# Professor - teaching metascience course                                                                      1
# Paleotology                                                                                                  1
# Experimental Psychology                                                                                      1
# PHD student - Nutrition/Psychology                                                                           1
# 1st PhD student - Psychology                                                                                 1
# Director of Research Services                                                                                1
# Microbiology & Immunology                                                                                    1
# Graduate student - Personality Psychology                                                                    1
# Psychology; Neuroscience; Human-Machine Interfaces                                                           1
# Director of the Social Science Data Archive                                                                  1
# Special Education                                                                                            1
# Science Coordinator                                                                                          1
# Professor - Psychology                                                                                       1
# Assistant Professor of Marketing                                                                             1
# business/psych                                                                                               1
# Research Associate, getting PhD in decision making. Interested in preregistration and Registered Reports     1
# Canada Research Chair in Behavioural Ecology                                                                 1
# Health Sciences Libraries                                                                                    1
# social-personality psychology                                                                                1
# social psychology/social neuroscience                                                                        1
# Management/Business                                                                                          1
# Neuroscience                                                                                                 1
# Cogntive neuroscience                                                                                        1
# Library                                                                                                      1
# Scholarly communication and digital scholarship                                                              1
# Biological and Earth Sciences                                                                                1
# Assistant Professor - Department of Human Development                                                        1
# Anthropology                                                                                                 1
# Associate University Librarian                                                                               1
# biology                                                                                                      1
# Name: Domain, Length: 88, dtype: int64

# %%
df.Domain.replace(['Psych', 'Econ', 'Library'], ['Psychology', 'Economics', 'Libraries'], inplace=True)

# %%
df.head(50)

# %% [markdown]
# I want to clean up the Domains column by putting unique disciplines into new columns. I first add all the values of the Domain column to a new list, called messy_domains.

# %%
messy_domains = df.Domain.values.tolist()
print(messy_domains[:10])
# Out:
# ['Psychology', 'Psychology', 'Psychology', 'Psychology', 'Psychology', 'Econ', 'Econ', '', 'Psychology', 'business/psych']

# %%
import re

clean_domains = []
pattern = '[;|/|&|,]'

for i in messy_domains:
    result = re.split(pattern, i)
    clean_domains.append(result)

print('-----')
print(clean_domains[:7])
# Out:
# -----
# [['Psychology'], ['Psychology'], ['Psychology'], ['Psychology'], ['Psychology'], ['Econ'], ['Econ']]

# %%
df['Clean Domains'] = clean_domains


df.head(30)
# Out:
#                City           State      Country          Region  \
# 0              Bonn                      Germany          Europe
# 1         Eindhoven                  Netherlands          Europe
# 2          Grenoble                       France          Europe
# 3         Riverside      California          USA   North America
# 4            Tacoma      Washington          USA   North America
# 5      Philadelphia    Pennsylvania          USA   North America
# 6          Berkeley      California          USA   North America
# 7         Cambridge                      England  United Kingdom
# 8           Toronto                       Canada   North America
# 9            Quebec                       Canada   North America
# 10          Ontario                       Canada   North America
# 11           Munich                      Germany          Europe
# 12      Mexico City                       Mexico   South America
# 13        Stockholm                       Sweden          Europe
# 14       Charlotte   North Carolina          USA   North America
# 15      Springfield        Missouri          USA   North America
# 16     Philadelphia    Pennsylvania          USA   North America
# 17      Gainesville         Florida          USA   North America
# 18    Santa Barbara      California          USA   North America
# 19  Charlottesville        Virginia          USA   North America
# 20     Juiz de Fora                       Brazil   South America
# 21        Corvallis          Oregon          USA   North America
# 22      Mexico City                       Mexico   North America
# 23            Delft                  Netherlands          Europe
# 24        Arlington        Virignia          USA   North America
# 25    Santa Barbara      California          USA   North America
# 26        San Diego      California          USA   North America
# 27        Allendale        Michigan          USA   North America
# 28      Minneapolis       Minnesota          USA   North America
# 29         Portland          Oregon          USA   North America
#
#                                          Organization  \
# 0                                MPI Collective Goods
# 1                                           Eindhoven
# 2                           Université Grenoble Alpes
# 3                University of California - Riverside
# 4                                    Pacific Lutheran
# 5                                   Haverford College
# 6                                               BITSS
# 7                             University of Cambridge
# 8                               University of Toronto
# 9                                              McGill
# 10                                  Queens University
# 11             Ludwig-Maximilians-Universität München
# 12
# 13                               Stockholm University
# 14            University of North Carolina- Charlotte
# 15                                     Missouri State
# 16                                  Haverford College
# 17                              University of Florida
# 18  National Center for Ecological Analysis and Sy...
# 19                             University of Virginia
# 20                 Federal University of Juiz de Fora
# 21                           Oregon State University
# 22           National Autonomous University of Mexico
# 23                     Delft University of Technology
# 24                          Center for Naval Analyses
# 25                                              NCEAS
# 26              University of California - San Diego
# 27                      Grand Valley State University
# 28                            University of Minnesota
# 29                                               OHSU
#
#                                          Domain Training Date  \
# 0                                    Psychology    2015-02-03
# 1                                    Psychology    2015-02-03
# 2                                    Psychology    2015-02-03
# 3                                    Psychology    2015-02-03
# 4                                    Psychology    2015-02-03
# 5                                          Econ    2015-02-03
# 6                                          Econ    2015-02-03
# 7                                                  2015-02-24
# 8                                    Psychology    2015-04-30
# 9                                business/psych    2015-04-30
# 10                        Library (engineering)    2015-04-30
# 11                                   Psychology    2015-04-30
# 12                                                 2015-04-30
# 13                             Medical Sciences    2015-04-30
# 14                          Management/Business    2015-04-30
# 15                                  psych/stats    2015-04-30
# 16                                    Libraries    2015-04-30
# 17                                                 2015-04-30
# 18                                      Ecology    2015-04-30
# 19                                      Library    2015-04-30
# 20                                                 2015-09-09
# 21                                    Libraries    2015-09-09
# 22     Applied Mathematics and Systems Research    2015-09-21
# 23                                   Psychology    2015-09-21
# 24  Political Science / International Relations    2015-09-21
# 25                                      ecology    2015-09-21
# 26        molecular bio/ cell bio/ neuroscience    2015-09-21
# 27                                   Psychology    2015-09-21
# 28                                                 2015-10-21
# 29                                 Neuroscience    2016-01-06
#
#                                      Clean Domains
# 0                                     [Psychology]
# 1                                     [Psychology]
# 2                                     [Psychology]
# 3                                     [Psychology]
# 4                                     [Psychology]
# 5                                           [Econ]
# 6                                           [Econ]
# 7                                               []
# 8                                     [Psychology]
# 9                                [business, psych]
# 10                         [Library (engineering)]
# 11                                    [Psychology]
# 12                                              []
# 13                              [Medical Sciences]
# 14                          [Management, Business]
# 15                                  [psych, stats]
# 16                                     [Libraries]
# 17                                              []
# 18                                       [Ecology]
# 19                                       [Library]
# 20                                              []
# 21                                     [Libraries]
# 22      [Applied Mathematics and Systems Research]
# 23                                    [Psychology]
# 24  [Political Science ,  International Relations]
# 25                                       [ecology]
# 26       [molecular bio,  cell bio,  neuroscience]
# 27                                    [Psychology]
# 28                                              []
# 29                                  [Neuroscience]

# %%
df1= pd.DataFrame(df['Clean Domains'].values.tolist()).add_prefix('Domain ')

df1.head(30)
# Out:
#                                     Domain 0                  Domain 1  \
# 0                                 Psychology                      None
# 1                                 Psychology                      None
# 2                                 Psychology                      None
# 3                                 Psychology                      None
# 4                                 Psychology                      None
# 5                                       Econ                      None
# 6                                       Econ                      None
# 7                                                                 None
# 8                                 Psychology                      None
# 9                                   business                     psych
# 10                     Library (engineering)                      None
# 11                                Psychology                      None
# 12                                                                None
# 13                          Medical Sciences                      None
# 14                                Management                  Business
# 15                                     psych                     stats
# 16                                 Libraries                      None
# 17                                                                None
# 18                                   Ecology                      None
# 19                                   Library                      None
# 20                                                                None
# 21                                 Libraries                      None
# 22  Applied Mathematics and Systems Research                      None
# 23                                Psychology                      None
# 24                        Political Science    International Relations
# 25                                   ecology                      None
# 26                             molecular bio                  cell bio
# 27                                Psychology                      None
# 28                                                                None
# 29                              Neuroscience                      None
#
#          Domain 2
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None
# 18           None
# 19           None
# 20           None
# 21           None
# 22           None
# 23           None
# 24           None
# 25           None
# 26   neuroscience
# 27           None
# 28           None
# 29           None

# %%
result = pd.concat([df, df1], axis=1)

result.head(30)
# Out:
#                City           State      Country          Region  \
# 0              Bonn                      Germany          Europe
# 1         Eindhoven                  Netherlands          Europe
# 2          Grenoble                       France          Europe
# 3         Riverside      California          USA   North America
# 4            Tacoma      Washington          USA   North America
# 5      Philadelphia    Pennsylvania          USA   North America
# 6          Berkeley      California          USA   North America
# 7         Cambridge                      England  United Kingdom
# 8           Toronto                       Canada   North America
# 9            Quebec                       Canada   North America
# 10          Ontario                       Canada   North America
# 11           Munich                      Germany          Europe
# 12      Mexico City                       Mexico   South America
# 13        Stockholm                       Sweden          Europe
# 14       Charlotte   North Carolina          USA   North America
# 15      Springfield        Missouri          USA   North America
# 16     Philadelphia    Pennsylvania          USA   North America
# 17      Gainesville         Florida          USA   North America
# 18    Santa Barbara      California          USA   North America
# 19  Charlottesville        Virginia          USA   North America
# 20     Juiz de Fora                       Brazil   South America
# 21        Corvallis          Oregon          USA   North America
# 22      Mexico City                       Mexico   North America
# 23            Delft                  Netherlands          Europe
# 24        Arlington        Virignia          USA   North America
# 25    Santa Barbara      California          USA   North America
# 26        San Diego      California          USA   North America
# 27        Allendale        Michigan          USA   North America
# 28      Minneapolis       Minnesota          USA   North America
# 29         Portland          Oregon          USA   North America
#
#                                          Organization  \
# 0                                MPI Collective Goods
# 1                                           Eindhoven
# 2                           Université Grenoble Alpes
# 3                University of California - Riverside
# 4                                    Pacific Lutheran
# 5                                   Haverford College
# 6                                               BITSS
# 7                             University of Cambridge
# 8                               University of Toronto
# 9                                              McGill
# 10                                  Queens University
# 11             Ludwig-Maximilians-Universität München
# 12
# 13                               Stockholm University
# 14            University of North Carolina- Charlotte
# 15                                     Missouri State
# 16                                  Haverford College
# 17                              University of Florida
# 18  National Center for Ecological Analysis and Sy...
# 19                             University of Virginia
# 20                 Federal University of Juiz de Fora
# 21                           Oregon State University
# 22           National Autonomous University of Mexico
# 23                     Delft University of Technology
# 24                          Center for Naval Analyses
# 25                                              NCEAS
# 26              University of California - San Diego
# 27                      Grand Valley State University
# 28                            University of Minnesota
# 29                                               OHSU
#
#                                          Domain Training Date  \
# 0                                    Psychology    2015-02-03
# 1                                    Psychology    2015-02-03
# 2                                    Psychology    2015-02-03
# 3                                    Psychology    2015-02-03
# 4                                    Psychology    2015-02-03
# 5                                          Econ    2015-02-03
# 6                                          Econ    2015-02-03
# 7                                                  2015-02-24
# 8                                    Psychology    2015-04-30
# 9                                business/psych    2015-04-30
# 10                        Library (engineering)    2015-04-30
# 11                                   Psychology    2015-04-30
# 12                                                 2015-04-30
# 13                             Medical Sciences    2015-04-30
# 14                          Management/Business    2015-04-30
# 15                                  psych/stats    2015-04-30
# 16                                    Libraries    2015-04-30
# 17                                                 2015-04-30
# 18                                      Ecology    2015-04-30
# 19                                      Library    2015-04-30
# 20                                                 2015-09-09
# 21                                    Libraries    2015-09-09
# 22     Applied Mathematics and Systems Research    2015-09-21
# 23                                   Psychology    2015-09-21
# 24  Political Science / International Relations    2015-09-21
# 25                                      ecology    2015-09-21
# 26        molecular bio/ cell bio/ neuroscience    2015-09-21
# 27                                   Psychology    2015-09-21
# 28                                                 2015-10-21
# 29                                 Neuroscience    2016-01-06
#
#                                      Clean Domains  \
# 0                                     [Psychology]
# 1                                     [Psychology]
# 2                                     [Psychology]
# 3                                     [Psychology]
# 4                                     [Psychology]
# 5                                           [Econ]
# 6                                           [Econ]
# 7                                               []
# 8                                     [Psychology]
# 9                                [business, psych]
# 10                         [Library (engineering)]
# 11                                    [Psychology]
# 12                                              []
# 13                              [Medical Sciences]
# 14                          [Management, Business]
# 15                                  [psych, stats]
# 16                                     [Libraries]
# 17                                              []
# 18                                       [Ecology]
# 19                                       [Library]
# 20                                              []
# 21                                     [Libraries]
# 22      [Applied Mathematics and Systems Research]
# 23                                    [Psychology]
# 24  [Political Science ,  International Relations]
# 25                                       [ecology]
# 26       [molecular bio,  cell bio,  neuroscience]
# 27                                    [Psychology]
# 28                                              []
# 29                                  [Neuroscience]
#
#                                     Domain 0                  Domain 1  \
# 0                                 Psychology                      None
# 1                                 Psychology                      None
# 2                                 Psychology                      None
# 3                                 Psychology                      None
# 4                                 Psychology                      None
# 5                                       Econ                      None
# 6                                       Econ                      None
# 7                                                                 None
# 8                                 Psychology                      None
# 9                                   business                     psych
# 10                     Library (engineering)                      None
# 11                                Psychology                      None
# 12                                                                None
# 13                          Medical Sciences                      None
# 14                                Management                  Business
# 15                                     psych                     stats
# 16                                 Libraries                      None
# 17                                                                None
# 18                                   Ecology                      None
# 19                                   Library                      None
# 20                                                                None
# 21                                 Libraries                      None
# 22  Applied Mathematics and Systems Research                      None
# 23                                Psychology                      None
# 24                        Political Science    International Relations
# 25                                   ecology                      None
# 26                             molecular bio                  cell bio
# 27                                Psychology                      None
# 28                                                                None
# 29                              Neuroscience                      None
#
#          Domain 2
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None
# 18           None
# 19           None
# 20           None
# 21           None
# 22           None
# 23           None
# 24           None
# 25           None
# 26   neuroscience
# 27           None
# 28           None
# 29           None

# %%
#let's read our file 
df = pd.read_csv('ambassadors_list.csv')

#drop unecessary columns that I don't need
df.drop(['First Name', 'Last Name', 'Email', 'Mailing Address', 'Prereg Challenge', 'ambassador training date'], axis=1, inplace=True)

#replace cells containing 'NaN' with a blank string (it looks prettier)
df = df.fillna('')

#add column labeled Full Address which combines City, State, and Country
#use numpy conditional statement to account for 'blank' State cells
df['Full Address'] = np.where(df['State'] == '', df['City'] + ', ' + df['Country'], df['City'] + ', ' + df['State'] + ', ' + df['Country'])

#Ignore the code below. If you decide not to do conditional statement, you can use this code instead. The above code looks a bit cleaner, but this also works fine. 
#df['Full Address'] = df['City'] + ', ' + df['State'] + ', ' + df['Country']


#let's see what our data look like 
df.head()

# %%
#make a list out of the Full Address column. This list will be used when we geocode Ambassador locations
dfToList = df['Full Address'].tolist()

# %% [markdown]
# ### Let's Do Geocoding!
# My original csv file of Ambassador data lists their location in 'city', 'state', 'country' form. In order to plot points on a map, having the coordinates (latitude and longitude) of each location is important.

# %%
with open('google_credentials.json') as creds:
    google_credentials = json.load(creds)

# %%
from geopy import geocoders
g = geocoders.GoogleV3(google_credentials['api_key']) #you need a GoogleV3 API key

#create empty lists for latitude and longitude
lats = []
lons = []
   
for i in dfToList:
    location = g.geocode(i, timeout=10)
    lats.append(location.latitude)
    lons.append(location.longitude)

# %%
#add longitudes and latitudes to my table 
df['Longitude'] = lons
df['Latitude'] = lats

#change order of columns (because I am perfectionist and want things in a certain order)
df = df[['City', 'State', 'Country', 'Full Address', 'Longitude', 'Latitude', 'Region', 'Institution/Organization', 'Domain']]

#save table to new CSV file and remove the Index from CSV file (you don't have to do this step)
df.to_csv('ambassadors_list_shortened.csv', index=False)

#let's see what our data look like
df.head()

# %% [markdown]
# ## Let's Make Maps!

# %%
#make the figure bigger
plt.figure(figsize=(16,12))

#set up map details
my_map = Basemap(projection='robin', lat_0=0, lon_0=0,
              resolution='l', area_thresh=1000.0)

#draws continents and coastlines
my_map.drawcoastlines()
#draws countries
my_map.drawcountries()
#fills in continents with color
my_map.fillcontinents(color='lightgray',lake_color='lightblue')
#cleans up map boundary and fills the ocean color
my_map.drawmapboundary(fill_color='lightblue')
#sets x to be longitude and y to be latitude
x,y = my_map(lons, lats)
#plots lat & lon 
my_map.plot(x, y, 'ro', markersize=5)


font_title = {'family': 'sans-serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 22,
        }

font_footer = {'family': 'sans-serif',
        'color':  'gray',
        'weight': 'italic',
        'size': 12,
        }

plt.title("COS Ambassador Locations", fontdict=font_title)
plt.figtext(0.3,0.21, "Over 220 COS Ambassadors are represented on this map. One dot corresponds to one Ambassador.")
plt.savefig('ambassador_locations.png')
plt.show()

# %%
#make the figure bigger
plt.figure(figsize=(16,12))

#setting up map details like type of map (aka 'projection')
my_map = Basemap(projection='cyl', llcrnrlat=-75,urcrnrlat=75,
            llcrnrlon=-180, urcrnrlon=180, resolution='c', area_thresh=1000.0)

#draws continents and coastlines
my_map.drawcoastlines()
#draws countries
my_map.drawcountries()
#fills in continents with color
my_map.fillcontinents(color='lightgray',lake_color='lightblue')
#cleans up map boundary and fills the ocean color
my_map.drawmapboundary(fill_color='lightblue')
#sets x to be longitude and y to be latitude
x,y = my_map(lons, lats)
#plots lat & lon 
my_map.plot(x, y, 'ro', markersize=5)

plt.show()

# %% [markdown]
# ### Part 2: Let's Make an Interactive Map!

# %%
import folium

# %%
#remember that CSV we saved earlier? I want to use it here. 
df = pd.read_csv('ambassadors_list_shortened.csv')

#let's see what our data look like
df.head()

# %%
#for the interactive map I want to create, I need three pieces of info: latitude, longitude, and address
#I create lists for latitude, longitude, and address
lat = list(df['Latitude'])
lon = list(df['Longitude'])
location = list(df['Full Address'])

#printed the first entry in my dataset to make sure it is what I anticipated
print(location[0])
print(lon[0])
print(lat[0])

# %%
map = folium.Map(location=[0,0], #latitude and longitude of where my map is centered when it loads on the screen
    tiles='CartoDB positron', #type of map projection
    zoom_start=1.5, #bigger zoom number, the closer in it will be 
    max_zoom=10)


for lat, lon, location in zip(lat, lon, location):
    folium.CircleMarker(location=[lat, lon], 
                       radius = 2,
                       color = 'blue',
                       popup = location).add_to(map)

# %%
#save our map as an html file 
map.save("ambassador_locations_map.html")

#let's see what our map looks like.
map
